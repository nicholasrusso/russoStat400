# %%
import pandas as pd
from salmon import *
# %matplotlib inline

# %%
x = LinearModel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6b1eaab4f9a3> in <module>()
# ----> 1 x = LinearModel()
#
# TypeError: __init__() missing 2 required positional arguments: 'explanatory' and 'response'

# %%
data = pd.read_csv("data/lsd.csv")
#data = data[data["AvgWinnings"] < 150000].reset_index(drop=True)
data.head()
# Out:
#     lsd   math
# 0  1.17  78.93
# 1  2.97  58.20
# 2  3.26  67.47
# 3  4.69  37.47
# 4  5.83  45.65

# %%
explanatory = Q("lsd")
response = Q("math")

# %%
model = LinearModel(explanatory, response)

# %%
model.fit(data)
model.plot()

# %%
model.residual_plots()
